# %% [markdown]
# <a href="https://colab.research.google.com/github/def-himani/MachineLearning/blob/main/Basics/Pandas/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas
#
# Used for data processing and analysis - especially for huge collection of data
#
# Dataframe:
#
# Its a 2D tabular datastructure with labeled axes (row and column)

# %% [markdown]
# ## Importing

# %%
# From sklearn

import pandas as pd
from sklearn.datasets import load_boston # not working for now - will come back to it later

boston_dataset = load_boston()
type(boston_dataset)

# %%
boston_df = pd.DataFrame(boston_dataset.data, columns = boston_dataset.feature_names)
boston_df.head()

# %%
# From CSV uploaded to colab
diabetes.df = pd.read_csv('/content/diabetes.csv')
