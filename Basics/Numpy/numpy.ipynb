# %% [markdown]
# <a href="https://colab.research.google.com/github/def-himani/MachineLearning/blob/main/Basics/Numpy/numpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Numpy - Numerical python
#
# + Faster than usual python lists
# + Can perform lots of mathematical operations in it

# %% [markdown]
# ## Testing speed of list and numpy arrays

# %%
from time import process_time

# %%
# LIST
py_list = [i for i in range(10000)]

start_time = process_time()

py_list = [i+5 for i in py_list]

end_time = process_time()

print(end_time - start_time)
# Out:
# 0.00046957599999997157

# %%
import numpy as np

# %%
# NUMPY Array
np_array = np.array([i for i in range(10000)])

start_time = process_time()

np_array += 5

end_time = process_time()


print(end_time - start_time)
# Out:
# 0.007956130999996702
